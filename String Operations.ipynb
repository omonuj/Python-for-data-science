# %%
a='Rob'
b='John'
c="Mike"

# %%
print(a)
print(b)
print(c)
# Out:
# Rob
# John
# Mike

# %%
print(type(a))
print(type(b))
print(type(c))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
len(a)
# Out:
# 3

# %%
str1 = "hello world"
