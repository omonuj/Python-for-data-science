# %%
a='Rob'
b='John'
c="Mike"

# %%
print(a)
print(b)
print(c)
# Out:
# Rob
# John
# Mike

# %%
print(type(a))
print(type(b))
print(type(c))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
len(a)
# Out:
# 3

# %%
str1 = "hello world"

# %%
str1[0:3]
# Out:
# 'hel'

# %%
str1[-1]
# Out:
# 'd'

# %%
str1[0:5]
# Out:
# 'hello'

# %%
str1[-3:]
# Out:
# 'rld'

# %%
str1
# Out:
# 'hello world'

# %%
str1[0:2]
# Out:
# 'he'

# %%
str1[-8:]
# Out:
# 'lo world'

# %%
new_str = str1[0:2] + 'x' + str1[-8:]

# %%
new_str
# Out:
# 'hexlo world'
