# %%
num = 100

if(num > 1999)
    print("Hello World!!")
else:
    print("Bye")
# Out:
#   File "<ipython-input-22-d5b984ec56ab>", line 3
#     if(num > 1999)
#                   ^
# SyntaxError: invalid syntax

# %%
num = 100

if(num > 1999):
    print("Hello World!!")
else:
print("Bye")
# Out:
#   File "<ipython-input-27-1bba5e7de7f0>", line 6
#     print("Bye")
#         ^
# IndentationError: expected an indented block

# %%
num = 100

if(num > 1999):
    print("Hello World!!")
else:
    print("Bye")
# Out:
# Bye

# %%
num = 100

new_number = num/0

print(new_number)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-29-8b651e720c66> in <module>
#       1 num = 100
#       2
# ----> 3 new_number = num/0
#       4
#       5 print(new_number)
#
# ZeroDivisionError: division by zero

# %%
num = 100

new_number = num/0.0000000000001

print(new_number)
# Out:
# 1000000000000000.0
