# %% [markdown]
# ## Functions

# %%
#x = 10

def even_or_odd(x):
    if x %2 == 0:
        print("Even")
    else:
        print("Odd")
        
even_or_odd(13)
# Out:
# Odd

# %% [markdown]
# #### Factorial

# %%
def fact_number(n):
    fact = 1
    
    for i in range(1,n+1):
        fact = fact *i
    return fact

fact_number(5)
# Out:
# 120

# %% [markdown]
# #### Sum of all natural numbers till the number provided
