# %%
name = 'mike'
print(name)
# Out:
# mike

# %%
name = input('enter your name: ')
print('welcome', name)
# Out:
# enter your name: xyz
# welcome xyz

# %%
a = True
b = 'True'

# %%
print(type(a))
print(type(b))
# Out:
# <class 'bool'>
# <class 'str'>

# %% [markdown]
# #### Typecasting

# %%
var = 2
type(var)
# Out:
# int

# %%
var1 = float(var)
type(var1)
# Out:
# float

# %%
var = 2.9
var_int = int(var)
print(var_int)
# Out:
# 2

# %%
int(var)
# Out:
# 2

# %%
var = 2
new_var = str(var)
