# %%
name = 'mike'
print(name)
# Out:
# mike

# %%
name = input('enter your name: ')
print('welcome', name)
# Out:
# enter your name: xyz
# welcome xyz

# %%
a = True
b = 'True'

# %%
print(type(a))
print(type(b))
# Out:
# <class 'bool'>
# <class 'str'>

# %% [markdown]
# #### Typecasting
