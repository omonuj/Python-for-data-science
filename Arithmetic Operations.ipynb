# %%
a=10
b=2

# %%
a=3
b=4
a**b
# Out:
# 81

# %%
a/b
# Out:
# 5.0

# %%
a-b
# Out:
# 8

# %%
a=50
b=8

# %%
a//b
# Out:
# 6

# %%
a//b --> Floor Division
Floor
Ceiling
# Out:
# 6

# %%
# Modulus/Reminder

a%b
# Out:
# 2

# %%
a=3
b=4
a**b
# Out:
# 81

# %%
# BODMAS

print((4*5)-9+6/7)
# Out:
# 11.857142857142858
