# %% [markdown]
# ## File Handling

# %% [markdown]
# #### Reading a file

# %%
file = open('test.txt', 'r')


for line in file:
    print(line)
# Out:
# Hello World
#
# My name is Satyajit Pattnaik
#
# Welcome to my Python course!!!!

# %%
file = open('test.txt', 'r')
print(file.read())
# Out:
# Hello World
# My name is Satyajit Pattnaik
# Welcome to my Python course!!!!

# %%
file = open('test.txt', 'r')
print(file.read(5))
# Out:
# Hello
